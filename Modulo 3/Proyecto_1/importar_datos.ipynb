# %%
##importar libreria

import pandas as pd

# %%
#importan datos

df = pd.read_csv('Human_Resources.csv')
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
## mostrar todas las columnas
pd.set_option('display.max_columns',None)

##mostrar las primeras filas
df.head(3)

##obtener resumen
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   MonthlyIncome             1467 non-null   float64
#  2   Attrition                 1470 non-null   object
#  3   BusinessTravel            1470 non-null   object
#  4   DailyRate                 1470 non-null   int64
#  5   Department                1469 non-null   object
#  6   DistanceFromHome          1470 non-null   int64
#  7   Education                 1470 non-null   int64
#  8   EducationField            1469 non-null   object
#  9   EmployeeCount             1470 non-null   int64
#  10  EmployeeNumber            1469 non-null   float64
#  11  EnvironmentSatisfaction   1470 non-null   int64
#  12  Gender                    1469 non-null   object
# ...

# %%
##filtrado de Valores unicos
df['Department'].unique()

df['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60])

# %%
##valores unicos para toda la tabla 
df.nunique()
# Out:
# Age                           43
# MonthlyIncome               1346
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    886
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1469
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyRate                 1425
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
df.columns.to_list ## lista de nombres de columnas

for name in df.columns.to_list():
    print (f'la columna {name} contiene los elementos {df[name].unique()}')
# Out:
# la columna Age contiene los elementos [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# la columna MonthlyIncome contiene los elementos [5993.   nan 2090. ... 9991. 5390. 4404.]
# la columna Attrition contiene los elementos ['Yes' 'No']
# la columna BusinessTravel contiene los elementos ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# la columna DailyRate contiene los elementos [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
# ...

# %%
## eliminar columnas que no ayuden al modelo

valores_unicos_n= df.nunique()

##traer solo valores
colum_sin_ayuda = valores_unicos_n[valores_unicos_n == 1].index.to_list()
colum_sin_ayuda
# Out:
# ['EmployeeCount', 'Over18', 'StandardHours']

# %%
## eliminacion de columnas
## una vez ejecuatado se debera volver a cargar la tabla
##df.drop(colum_sin_ayuda,axis=1,inplace=True)
#df.drop(colum_sin_ayuda,axis=1)
df.head(5)
df
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 1      49            NaN        No  Travel_Frequently        279
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
## resumen estadistico de la tabla
df.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1470.000000    1467.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810    6505.155419   802.485714          9.192517     2.912925
# std       9.135373    4711.297846   403.509100          8.106864     1.024165
# min      18.000000    1009.000000   102.000000          1.000000     1.000000
# 25%      30.000000    2911.000000   465.000000          2.000000     2.000000
# 50%      36.000000    4908.000000   802.000000          7.000000     3.000000
# 75%      43.000000    8378.000000  1157.000000         14.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1469.000000              1470.000000  1470.000000
# mean             1.0     1025.556161                 2.721769    65.891156
# ...

# %%
##filtro por columna 
## & sirve para filtar por mas atributos, cada atributo se cerrada en () puese ser | or &
Siguen = df[df['Attrition'] == 'No']
No_Siguen = df[df['Attrition'] == 'Yes']

Siguen.describe()
# Out:
#                Age  MonthlyIncome    DailyRate  DistanceFromHome    Education  \
# count  1233.000000    1231.000000  1233.000000       1233.000000  1233.000000
# mean     37.561233    6837.504468   812.504461          8.915653     2.927007
# std       8.888360    4820.415800   403.208379          8.012633     1.027002
# min      18.000000    1051.000000   102.000000          1.000000     1.000000
# 25%      31.000000    3211.500000   477.000000          2.000000     2.000000
# 50%      36.000000    5206.000000   817.000000          7.000000     3.000000
# 75%      43.000000    8835.500000  1176.000000         13.000000     4.000000
# max      60.000000   19999.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1233.0     1232.000000              1233.000000  1233.000000
# mean             1.0     1028.482143                 2.771290    65.952149
# ...

# %%
No_Siguen.describe()
# Out:
#               Age  MonthlyIncome    DailyRate  DistanceFromHome   Education  \
# count  237.000000     236.000000   237.000000        237.000000  237.000000
# mean    33.607595    4771.588983   750.362869         10.632911    2.839662
# std      9.689350    3640.097444   401.899519          8.452525    1.008244
# min     18.000000    1009.000000   103.000000          1.000000    1.000000
# 25%     28.000000    2371.500000   408.000000          3.000000    2.000000
# 50%     32.000000    3187.000000   699.000000          9.000000    3.000000
# 75%     39.000000    5850.000000  1092.000000         17.000000    4.000000
# max     58.000000   19859.000000  1496.000000         29.000000    5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction  HourlyRate  \
# count          237.0      237.000000               237.000000  237.000000
# mean             1.0     1010.345992                 2.464135   65.573840
# ...

# %%
## kaggle para obtener fuentes de datos
##uci machine learnig repository

# %% [markdown]
# ## Ejercicio valores nulos

# %%
df.isnull()
# Out:
#         Age  MonthlyIncome  Attrition  BusinessTravel  DailyRate  Department  \
# 0     False          False      False           False      False       False
# 1     False           True      False           False      False       False
# 2     False          False      False           False      False       False
# 3     False          False      False           False      False       False
# 4     False          False      False           False      False       False
# ...     ...            ...        ...             ...        ...         ...
# 1465  False          False      False           False      False       False
# 1466  False          False      False           False      False       False
# 1467  False          False      False           False      False       False
# 1468  False          False      False           False      False       False
# 1469  False          False      False           False      False       False
#
# ...

# %%
## traer los valores nulos
valores_nulos = df.isnull().sum()
valores_nulos
# Out:
# Age                         0
# MonthlyIncome               3
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  1
# DistanceFromHome            0
# Education                   0
# EducationField              1
# EmployeeCount               0
# EmployeeNumber              1
# EnvironmentSatisfaction     0
# Gender                      1
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     1
# JobSatisfaction             0
# MaritalStatus               1
# MonthlyRate                 2
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           1
# PerformanceRating           1
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
## % datos nulos
porce = valores_nulos / len(df)*100
porce
# Out:
# Age                         0.000000
# MonthlyIncome               0.204082
# Attrition                   0.000000
# BusinessTravel              0.000000
# DailyRate                   0.000000
# Department                  0.068027
# DistanceFromHome            0.000000
# Education                   0.000000
# EducationField              0.068027
# EmployeeCount               0.000000
# EmployeeNumber              0.068027
# EnvironmentSatisfaction     0.000000
# Gender                      0.068027
# HourlyRate                  0.000000
# JobInvolvement              0.000000
# JobLevel                    0.000000
# JobRole                     0.068027
# JobSatisfaction             0.000000
# MaritalStatus               0.068027
# MonthlyRate                 0.136054
# NumCompaniesWorked          0.000000
# Over18                      0.000000
# OverTime                    0.000000
# PercentSalaryHike           0.068027
# PerformanceRating           0.068027
# ...

# %%
## eliminar nulos
## investigar diferentes procesos de eliminación

df_2 = df.dropna(axis=0)
df_2.isnull().sum()

df_2
# Out:
#       Age  MonthlyIncome Attrition     BusinessTravel  DailyRate  \
# 0      41         5993.0       Yes      Travel_Rarely       1102
# 2      37         2090.0       Yes      Travel_Rarely       1373
# 3      33         2909.0        No  Travel_Frequently       1392
# 4      27         3468.0        No      Travel_Rarely        591
# 5      32         3068.0        No  Travel_Frequently       1005
# ...   ...            ...       ...                ...        ...
# 1465   36         2571.0        No  Travel_Frequently        884
# 1466   39         9991.0        No      Travel_Rarely        613
# 1467   27         6142.0        No      Travel_Rarely        155
# 1468   49         5390.0        No  Travel_Frequently       1023
# 1469   34         4404.0        No      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
## eliminar por atributo, columna

# %%
##instalacion libreria scikit-learn
##%pip install -U scikit-learn

# %%
## IMPUTACION DE DATOS -> SUSTITUCION DE DATOS


##from sklearn.impute import SimpleImputer
## por default sustiura los valores nulos/faltantes
##impute_numeric = SimpleImputer(strategy='mean')
##numeric_columns = df.select_dtypes(include='number').columns

##sustitucion de valores nulos / k-near neighbor
from sklearn.impute import KNNImputer
impute_numeric = KNNImputer(strategy ='mean')
##numeric_colums = df.select_dtypes(include='number').columns
##df[numeric_colums] = impute_numeric.fit_transform (df[numeric_colums])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 11
#       1 ## IMPUTACION DE DATOS -> SUSTITUCION DE DATOS
#       2
#       3
#    (...)
#       8
#       9 ##sustitucion de valores nulos / k-near neighbor
#      10 from sklearn.impute import KNNImputer
# ---> 11 impute_numeric = KNNImputer(strategy ='mean')
#      12 ##numeric_colums = df.select_dtypes(include='number').columns
#      13 ##df[numeric_colums] = impute_numeric.fit_transform (df[numeric_colums])
#
# TypeError: KNNImputer.__init__() got an unexpected keyword argument 'strategy'

# %%
## sustituir en categorias nulas
from sklearn.impute import SimpleImputer

impute_categorico = SimpleImputer(strategy='most_frequent')
categorical_columns = df.select_dtypes(include='object').columns
df[categorical_columns] = impute_.fit_transform (df[categorical_columns])

# %% [markdown]
# ## tratar con datos

# %%
## mutate de valores de categorias >>>> 0 a 1

# %%
## traer los datos
##for name in df.columns.to_list():
  ##  print(f'{name}:{df[name].unique()}')
    ##print('\n')

df.info()

# %%
## variables nominales
## convierte las categorias en tantas columnas dando valores false/true
df = pd.get_dummies(df,columns=['Department','BusinessTravel','EducationField','Gender','JobRole','MaritalStatus'])

# %%
df.to_csv('Preposeced.csv',index=False)

# %% [markdown]
# # Deteccion de valores atipicos

# %%
##!pip install seaborn

# %%
##import matplotlib.pyplot as plt
import seaborn as sns ## investigar sobre esta libreria
import numpy as np

# %% [markdown]
# ## Simulacion de datos atipicos

# %%
Q1 = df['Age'].quantile(0.25)
Q3 = df['Age'].quantile(0.75)
IQR = Q3-Q1

Lim_inf = Q1 - 1.5*IQR
Lim_inf

Lim_Sup = Q3 + 1.5*IQR
Lim_Sup
# Out:
# np.float64(62.5)

# %%
df_test = df.copy()  # creacion de copia de datos limpios

indices = np.random.choice(df_test.index, 2, replace=False)
df_test.loc[indices[0],'Age'] += 3 * IQR
df_test.loc[indices[1],'Age'] += 3 * IQR

# %%
##Diagrama de cajas y bigotes
df_test.boxplot(column='Age')
plt.show()

# %%
##Prueba para valores atipicos

Q1_t = df_test['Age'].quantile(0.25)
Q3_T = df_test['Age'].quantile(0.75)
IQR = Q3-Q1

Lim_inf = Q1_t - 1.5*IQR
print(Lim_inf)

Lim_Sup = Q3_T + 1.5*IQR
print(Lim_Sup)
# Out:
# 10.5
# 62.5

# %% [markdown]
# # Ejercicio 3
#
# ## tomar 3 columnas y calcular valores atipicos

# %%
##Diagrama de cajas y bigotes, columna 1
df_test.boxplot(column='MonthlyRate')
plt.show()

# %%
Q1_e1 = df['MonthlyRate'].quantile(0.25)
Q3_e1 = df['MonthlyRate'].quantile(0.75)
IQR = Q3_e1-Q1_e1

Lim_inf = Q1_e1 - 1.5*IQR
print(Lim_inf)

Lim_Sup = Q3_e1 + 1.5*IQR
print(Lim_Sup)
# Out:
# -10585.5
# 39092.5

# %%
sns.displot(x=df['MonthlyRate'])
plt.show()

# %%
##Diagrama de cajas y bigotes, columna 2
df_test.boxplot(column='HourlyRate')
plt.show()

# %%
Q1_e2 = df['MonthlyRate'].quantile(0.25)
Q3_e2 = df['MonthlyRate'].quantile(0.75)
IQR = Q3_e2-Q1_e2

Lim_inf = Q1_e2 - 1.5*IQR
print(Lim_inf)

Lim_Sup = Q3_e2 + 1.5*IQR
print(Lim_Sup)
# Out:
# -10585.5
# 39092.5

# %%
##Diagrama de cajas y bigotes, columna 3
df_test.boxplot(column='MonthlyIncome')
plt.show()

# %%
Q1_e3 = df['MonthlyIncome'].quantile(0.25)
Q3_e3 = df['MonthlyIncome'].quantile(0.75)
IQR = Q3_e3-Q1_e3

Lim_inf = Q1_e3 - 1.5*IQR
print(Lim_inf)

Lim_Sup = Q3_e3 + 1.5*IQR
print(Lim_Sup)
# Out:
# -5289.5
# 16578.5

# %%
##metodo para ver que variable pudiera tener valores atipicos

df.hist(bins=30,figsize=(30,30))
plt.show()

# %% [markdown]
# # Clasificacion fronteras de separacion / i trees / bosques de aislamiento

# %%
## Libreria para este algoritmo
from sklearn.ensemble import IsolationForest

# %%
## Entrenamiento de algoritmo
forest = IsolationForest(contamination='auto').fit(df[['Age']])

# %%
## Prediccion con modelo
forest.predict(df[['Age']])

## para llamar los datos los asignas a una variable, los agregas como columna a tu data frame original
#  y llamas los nulos o no

# %% [markdown]
# ## Tabls de correlacion

# %%
import pandas as pd
import seaborn as sns

# %%
## formula para obtener correlacion
correlaciones = df.corr()

f,ax = plt.subplots(figsize=(50,50))
sns.heatmap(correlaciones,annot=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[56], line 2
#       1 ## formula para obtener correlacion
# ----> 2 correlaciones = df.corr()
#       4 f,ax = plt.subplots(figsize=(50,50))
#       5 sns.heatmap(correlaciones,annot=True)
#
# File c:\Users\mvelazquez\AppData\Local\anaconda3\envs\Diplomado\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\mvelazquez\AppData\Local\anaconda3\envs\Diplomado\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# ...

# %%
sns.pairplot(df,hue='Education',vars=['YearsAtCompany','MonthlyIncome'])

# %%
#Separacion de datos por tipo de variable

x = df[[c]] #variables independientes
y= df[[]] #Variable dependiente
